# %% [markdown]
# # Loading the data from IMDB

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## The Data

# %%
basics_url ="https://datasets.imdbws.com/title.basics.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"

# %% [markdown]
# ## Loading TSV's with Pandas

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
basics
# Out:
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10265839  tt9916848  tvEpisode              Episode #3.17
# 10265840  tt9916850  tvEpisode              Episode #3.19
# 10265841  tt9916852  tvEpisode              Episode #3.20
# 10265842  tt9916856      short                   The Wind
# 10265843  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                       originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                        Carmencita       0      1894      \N              1
# 1            Le clown et ses chiens       0      1892      \N              5
# 2                    Pauvre Pierrot       0      1892      \N              4
# 3                       Un bon bock       0      1892      \N             12
# 4                  Blacksmith Scene       0      1893      \N              1
# ...                             ...     ...       ...     ...            ...
# 10265839              Episode #3.17       0      2009      \N             \N
# 10265840              Episode #3.19       0      2010      \N             \N
# 10265841              Episode #3.20       0      2010      \N             \N
# 10265842                   The Wind       0      2015      \N             27
# 10265843  Horrid Henry Knows It All       0      2014      \N             10
#
#                               genres
# 0                  Documentary,Short
# 1                    Animation,Short
# 2           Animation,Comedy,Romance
# 3                    Animation,Short
# 4                       Comedy,Short
# ...                              ...
# 10265839         Action,Drama,Family
# 10265840         Action,Drama,Family
# 10265841         Action,Drama,Family
# 10265842                       Short
# 10265843  Adventure,Animation,Comedy
#
# [10265844 rows x 9 columns]

# %%
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2003
# 1        tt0000002            5.8       269
# 2        tt0000003            6.5      1898
# 3        tt0000004            5.5       178
# 4        tt0000005            6.2      2683
# ...            ...            ...       ...
# 1363560  tt9916730            7.6        11
# 1363561  tt9916766            7.0        22
# 1363562  tt9916778            7.2        36
# 1363563  tt9916840            8.8         6
# 1363564  tt9916880            8.2         6
#
# [1363565 rows x 3 columns]

# %%
akas = pd.read_csv(akas_url,sep='\t', low_memory=False)
akas
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 37595399  tt9916852         5             Episódio #3.20     PT       pt
# 37595400  tt9916852         6             Episodio #3.20     IT       it
# 37595401  tt9916852         7               एपिसोड #3.20     IN       hi
# 37595402  tt9916856         1                   The Wind     DE       \N
# 37595403  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# 0         imdbDisplay             \N               0
# 1                  \N  literal title               0
# 2         imdbDisplay             \N               0
# 3         imdbDisplay             \N               0
# 4         imdbDisplay             \N               0
# ...               ...            ...             ...
# 37595399           \N             \N               0
# 37595400           \N             \N               0
# 37595401           \N             \N               0
# 37595402  imdbDisplay             \N               0
# 37595403     original             \N               1
#
# [37595404 rows x 8 columns]

# %% [markdown]
# # Specifications
# # Required Preprocessing - Details

# %% [markdown]
# # Filtering/Cleaning Steps:
#
# ### Title Basics:
#
# **Replace "\N" with np.nan**

# %%
basics.replace({'\\N':np.nan}, inplace=True)

# %%
for col in basics:
    print('Column {} has {} missing values'.format(col,basics[col].isnull().sum()))
# Out:
# Column tconst has 0 missing values
# Column titleType has 0 missing values
# Column primaryTitle has 17 missing values
# Column originalTitle has 17 missing values
# Column isAdult has 1 missing values
# Column startYear has 1373989 missing values
# Column endYear has 10151818 missing values
# Column runtimeMinutes has 7171328 missing values
# Column genres has 459016 missing values

# %% [markdown]
# * **Eliminate movies that are null for runtimeMinutes**

# %%
basics = basics[basics['runtimeMinutes'].notna()]
basics
# Out:
#              tconst  titleType                    primaryTitle  \
# 0         tt0000001      short                      Carmencita
# 1         tt0000002      short          Le clown et ses chiens
# 2         tt0000003      short                  Pauvre Pierrot
# 3         tt0000004      short                     Un bon bock
# 4         tt0000005      short                Blacksmith Scene
# ...             ...        ...                             ...
# 10265794  tt9916754      movie  Chico Albuquerque - Revelações
# 10265800  tt9916766  tvEpisode                  Episode #10.15
# 10265835  tt9916840  tvEpisode      Horrid Henry's Comic Caper
# 10265842  tt9916856      short                        The Wind
# 10265843  tt9916880  tvEpisode       Horrid Henry Knows It All
#
#                            originalTitle isAdult startYear endYear  \
# 0                             Carmencita       0      1894     NaN
# 1                 Le clown et ses chiens       0      1892     NaN
# 2                         Pauvre Pierrot       0      1892     NaN
# 3                            Un bon bock       0      1892     NaN
# 4                       Blacksmith Scene       0      1893     NaN
# ...                                  ...     ...       ...     ...
# 10265794  Chico Albuquerque - Revelações       0      2013     NaN
# 10265800                  Episode #10.15       0      2019     NaN
# 10265835      Horrid Henry's Comic Caper       0      2014     NaN
# 10265842                        The Wind       0      2015     NaN
# 10265843       Horrid Henry Knows It All       0      2014     NaN
#
#          runtimeMinutes                       genres
# 0                     1            Documentary,Short
# 1                     5              Animation,Short
# 2                     4     Animation,Comedy,Romance
# 3                    12              Animation,Short
# 4                     1                 Comedy,Short
# ...                 ...                          ...
# 10265794             49                  Documentary
# 10265800             43  Family,Game-Show,Reality-TV
# 10265835             11   Adventure,Animation,Comedy
# 10265842             27                        Short
# 10265843             10   Adventure,Animation,Comedy
#
# [3094516 rows x 9 columns]

# %%
basics['runtimeMinutes'].isna().sum()
# Out:
# 0

# %% [markdown]
# * **Eliminate movies that are null for genre**

# %%
basics['genres'].isnull().sum()
# Out:
# 80832

# %%
basics = basics[basics['genres'].notna()]

# %%
basics['genres'].isnull().sum()
# Out:
# 0

# %% [markdown]
# * **keep only titleType==Movie**

# %%
basics = basics[basics['titleType'] == 'movie']
basics
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# 672       tt0000679     movie
# ...             ...       ...
# 10265694  tt9916538     movie
# 10265735  tt9916622     movie
# 10265762  tt9916680     movie
# 10265784  tt9916730     movie
# 10265794  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# 672                          The Fairylogue and Radio-Plays
# ...                                                     ...
# 10265694                                Kuambil Lagi Hatiku
# 10265735        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10265762  De la ilusión al desconcierto: cine colombiano...
# 10265784                                             6 Gunn
# 10265794                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult startYear  \
# 8                                                Miss Jerry       0      1894
# 144                           The Corbett-Fitzsimmons Fight       0      1897
# 570                             The Story of the Kelly Gang       0      1906
# 587                                       L'enfant prodigue       0      1907
# 672                          The Fairylogue and Radio-Plays       0      1908
# ...                                                     ...     ...       ...
# 10265694                                Kuambil Lagi Hatiku       0      2019
# 10265735        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 10265762  De la ilusión al desconcierto: cine colombiano...       0      2007
# 10265784                                             6 Gunn       0      2017
# 10265794                     Chico Albuquerque - Revelações       0      2013
#
#          endYear runtimeMinutes                      genres
# 8            NaN             45                     Romance
# 144          NaN            100      Documentary,News,Sport
# 570          NaN             70  Action,Adventure,Biography
# 587          NaN             90                       Drama
# 672          NaN            120           Adventure,Fantasy
# ...          ...            ...                         ...
# 10265694     NaN            123                       Drama
# 10265735     NaN             57                 Documentary
# 10265762     NaN            100                 Documentary
# 10265784     NaN            116                       Drama
# 10265794     NaN             49                 Documentary
#
# [391282 rows x 9 columns]

# %% [markdown]
# * **keep startYear 2000-2022**

# %%
basics = basics[(basics['startYear'] > '2000') & (basics['startYear'] < '2022')]
basics
# Out:
#              tconst titleType  \
# 13081     tt0013274     movie
# 34800     tt0035423     movie
# 61111     tt0062336     movie
# 67485     tt0068865     movie
# 67663     tt0069049     movie
# ...             ...       ...
# 10265694  tt9916538     movie
# 10265735  tt9916622     movie
# 10265762  tt9916680     movie
# 10265784  tt9916730     movie
# 10265794  tt9916754     movie
#
#                                                primaryTitle  \
# 13081                           Istoriya grazhdanskoy voyny
# 34800                                        Kate & Leopold
# 61111     The Tango of the Widower and Its Distorting Mi...
# 67485                                   Lives of Performers
# 67663                            The Other Side of the Wind
# ...                                                     ...
# 10265694                                Kuambil Lagi Hatiku
# 10265735        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10265762  De la ilusión al desconcierto: cine colombiano...
# 10265784                                             6 Gunn
# 10265794                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult startYear  \
# 13081                           Istoriya grazhdanskoy voyny       0      2021
# 34800                                        Kate & Leopold       0      2001
# 61111             El tango del viudo y su espejo deformante       0      2020
# 67485                                   Lives of Performers       0      2016
# 67663                            The Other Side of the Wind       0      2018
# ...                                                     ...     ...       ...
# 10265694                                Kuambil Lagi Hatiku       0      2019
# 10265735        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 10265762  De la ilusión al desconcierto: cine colombiano...       0      2007
# 10265784                                             6 Gunn       0      2017
# 10265794                     Chico Albuquerque - Revelações       0      2013
#
#          endYear runtimeMinutes                  genres
# 13081        NaN             94             Documentary
# 34800        NaN            118  Comedy,Fantasy,Romance
# 61111        NaN             70                   Drama
# 67485        NaN             90                   Drama
# 67663        NaN            122                   Drama
# ...          ...            ...                     ...
# 10265694     NaN            123                   Drama
# 10265735     NaN             57             Documentary
# 10265762     NaN            100             Documentary
# 10265784     NaN            116                   Drama
# 10265794     NaN             49             Documentary
#
# [208231 rows x 9 columns]

# %% [markdown]
# * **Eliminate movies that include "Documentary" in genre**

# %%
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
(basics['genres'] == 'documentary').sum()
# Out:
# 0

# %%
basics
# Out:
#              tconst titleType  \
# 34800     tt0035423     movie
# 61111     tt0062336     movie
# 67485     tt0068865     movie
# 67663     tt0069049     movie
# 80548     tt0082328     movie
# ...             ...       ...
# 10265526  tt9916190     movie
# 10265565  tt9916270     movie
# 10265610  tt9916362     movie
# 10265694  tt9916538     movie
# 10265784  tt9916730     movie
#
#                                                primaryTitle  \
# 34800                                        Kate & Leopold
# 61111     The Tango of the Widower and Its Distorting Mi...
# 67485                                   Lives of Performers
# 67663                            The Other Side of the Wind
# 80548                                    Embodiment of Evil
# ...                                                     ...
# 10265526                                          Safeguard
# 10265565                           Il talento del calabrone
# 10265610                                              Coven
# 10265694                                Kuambil Lagi Hatiku
# 10265784                                             6 Gunn
#
#                                       originalTitle isAdult startYear endYear  \
# 34800                                Kate & Leopold       0      2001     NaN
# 61111     El tango del viudo y su espejo deformante       0      2020     NaN
# 67485                           Lives of Performers       0      2016     NaN
# 67663                    The Other Side of the Wind       0      2018     NaN
# 80548                         Encarnação do Demônio       0      2008     NaN
# ...                                             ...     ...       ...     ...
# 10265526                                  Safeguard       0      2020     NaN
# 10265565                   Il talento del calabrone       0      2020     NaN
# 10265610                                   Akelarre       0      2020     NaN
# 10265694                        Kuambil Lagi Hatiku       0      2019     NaN
# 10265784                                     6 Gunn       0      2017     NaN
#
#          runtimeMinutes                     genres
# 34800               118     Comedy,Fantasy,Romance
# 61111                70                      Drama
# 67485                90                      Drama
# 67663               122                      Drama
# 80548                94                     Horror
# ...                 ...                        ...
# 10265526             95  Action,Adventure,Thriller
# 10265565             84                   Thriller
# 10265610             92              Drama,History
# 10265694            123                      Drama
# 10265784            116                      Drama
#
# [136521 rows x 9 columns]

# %% [markdown]
# * **Keep only US movies**

# %%
akas = akas[akas['region'] == 'US']
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 37594930  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 37595000  tt9916620         1                          The Copeland Case
# 37595089  tt9916702         1              Loving London: The Playground
# 37595132  tt9916756         1                   Pretty Pretty Black Girl
# 37595148  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US       \N  imdbDisplay                     \N               0
# 14           US       \N           \N  literal English title               0
# 33           US       \N  imdbDisplay                     \N               0
# 36           US       \N  alternative                     \N               0
# 41           US       \N  alternative                     \N               0
# ...         ...      ...          ...                    ...             ...
# 37594930     US       \N  imdbDisplay                     \N               0
# 37595000     US       \N  imdbDisplay                     \N               0
# 37595089     US       \N           \N                     \N               0
# 37595132     US       \N  imdbDisplay                     \N               0
# 37595148     US       \N  imdbDisplay                     \N               0
#
# [1473807 rows x 8 columns]

# %% [markdown]
# * **Replace "\N" with np.nan**

# %%
akas.replace({'\\N':np.nan}, inplace=True)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_19024\3673592228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   akas.replace({'\\N':np.nan}, inplace=True)

# %% [markdown]
# ## Filtering one dataframe based on another
#
# Next, we will filter the basics df to only include the movies that are present in the filter akas dataframe. This is how we will ultimately be able to filter the movies by the region being in the US.

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers = basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34800        True
# 61111        True
# 67485        True
# 67663        True
# 80548        True
#             ...
# 10265526     True
# 10265565    False
# 10265610     True
# 10265694    False
# 10265784    False
# Name: tconst, Length: 136521, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#              tconst titleType  \
# 34800     tt0035423     movie
# 61111     tt0062336     movie
# 67485     tt0068865     movie
# 67663     tt0069049     movie
# 80548     tt0082328     movie
# ...             ...       ...
# 10264983  tt9914942     movie
# 10265377  tt9915872     movie
# 10265517  tt9916170     movie
# 10265526  tt9916190     movie
# 10265610  tt9916362     movie
#
#                                                primaryTitle  \
# 34800                                        Kate & Leopold
# 61111     The Tango of the Widower and Its Distorting Mi...
# 67485                                   Lives of Performers
# 67663                            The Other Side of the Wind
# 80548                                    Embodiment of Evil
# ...                                                     ...
# 10264983                             Life Without Sara Amat
# 10265377                               The Last White Witch
# 10265517                                      The Rehearsal
# 10265526                                          Safeguard
# 10265610                                              Coven
#
#                                       originalTitle isAdult startYear endYear  \
# 34800                                Kate & Leopold       0      2001     NaN
# 61111     El tango del viudo y su espejo deformante       0      2020     NaN
# 67485                           Lives of Performers       0      2016     NaN
# 67663                    The Other Side of the Wind       0      2018     NaN
# 80548                         Encarnação do Demônio       0      2008     NaN
# ...                                             ...     ...       ...     ...
# 10264983                 La vida sense la Sara Amat       0      2019     NaN
# 10265377              Boku no kanojo wa mahoutsukai       0      2019     NaN
# 10265517                                   O Ensaio       0      2019     NaN
# 10265526                                  Safeguard       0      2020     NaN
# 10265610                                   Akelarre       0      2020     NaN
#
#          runtimeMinutes                     genres
# 34800               118     Comedy,Fantasy,Romance
# 61111                70                      Drama
# 67485                90                      Drama
# 67663               122                      Drama
# 80548                94                     Horror
# ...                 ...                        ...
# 10264983             74                      Drama
# 10265377             97       Comedy,Drama,Fantasy
# 10265517             51                      Drama
# 10265526             95  Action,Adventure,Thriller
# 10265610             92              Drama,History
#
# [80699 rows x 9 columns]

# %% [markdown]
# ### Ratings:
# * **Replace "\N" with np.nan (if any)**

# %%
ratings.replace({'\\N':np.nan}, inplace=True)

# %%
for col in ratings:
    print('Column {} has {} missing values'.format(col,ratings[col].isnull().sum()))
# Out:
# Column tconst has 0 missing values
# Column averageRating has 0 missing values
# Column numVotes has 0 missing values

# %% [markdown]
# **Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)**

# %%
keepers = ratings['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1363560    False
# 1363561    False
# 1363562    False
# 1363563    False
# 1363564    False
# Name: tconst, Length: 1363565, dtype: bool

# %%
ratings = ratings[keepers]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2003
# 1        tt0000002            5.8       269
# 4        tt0000005            6.2      2683
# 5        tt0000006            5.0       183
# 6        tt0000007            5.4       839
# ...            ...            ...       ...
# 1363527  tt9916200            8.1       238
# 1363528  tt9916204            8.2       275
# 1363535  tt9916348            8.3        18
# 1363536  tt9916362            6.4      5583
# 1363541  tt9916428            3.5        17
#
# [512735 rows x 3 columns]

# %% [markdown]
# ## Creating a "Data" folder.

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# []

# %% [markdown]
# ## Saving Compressed .csv.gz Files

# %%
## Save current dataframe to file.
basics.to_csv("Data/basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics_ = pd.read_csv("Data/basics.csv.gz", low_memory = False)
basics_.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0082328     movie                                 Embodiment of Evil
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El tango del viudo y su espejo deformante        0       2020      NaN
# 2                        Lives of Performers        0       2016      NaN
# 3                 The Other Side of the Wind        0       2018      NaN
# 4                      Encarnação do Demônio        0       2008      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              90                   Drama
# 3             122                   Drama
# 4              94                  Horror

# %%
ratings.to_csv("Data/ratings.csv.gz",compression='gzip',index=False)

# %%
ratings_ = pd.read_csv("Data/ratings.csv.gz", low_memory = False)
ratings_.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2003
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2683
# 3  tt0000006            5.0       183
# 4  tt0000007            5.4       839

# %%
akas.to_csv("Data/akas.csv.gz",compression='gzip',index=False)

# %%
akas_ = pd.read_csv("Data/akas.csv.gz", low_memory = False)
akas_.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %% [markdown]
# ## Deliverable

# %%
basics_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80699 entries, 0 to 80698
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          80699 non-null  object
#  1   titleType       80699 non-null  object
#  2   primaryTitle    80698 non-null  object
#  3   originalTitle   80698 non-null  object
#  4   isAdult         80699 non-null  int64
#  5   startYear       80699 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  80699 non-null  int64
#  8   genres          80699 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 5.5+ MB

# %%
ratings_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512735 entries, 0 to 512734
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         512735 non-null  object
#  1   averageRating  512735 non-null  float64
#  2   numVotes       512735 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.7+ MB

# %%
akas_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1473807 entries, 0 to 1473806
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1473807 non-null  object
#  1   ordering         1473807 non-null  int64
#  2   title            1473805 non-null  object
#  3   region           1473807 non-null  object
#  4   language         4182 non-null     object
#  5   types            984902 non-null   object
#  6   attributes       47663 non-null    object
#  7   isOriginalTitle  1472466 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 90.0+ MB
